# %% [markdown]
# ##  App Review Trend Analysis using Agentic AI
#
# ### Problem Statement
# Product teams need to understand recurring issues, feature requests, and feedback trends from
# app store reviews. However, user reviews are noisy and often describe the same issue using
# different language.
#
# ### Objective
# Build an agentic AI system that:
# - Consumes daily Google Play Store reviews (batch-wise)
# - Extracts high-recall topics (issues, requests, feedback)
# - Consolidates semantically similar topics into canonical categories
# - Tracks topic frequency daily
# - Produces a rolling **T-30 trend report**
#
# ### Why Agentic AI
# Traditional topic modeling (LDA, TopicBERT) fails to reliably merge semantically similar topics.
# This system uses:
# - LLM-based topic extraction agents
# - Embedding-based semantic consolidation
# - Persistent topic memory across days

# %%
# !pip install google-play-scraper pandas numpy sentence-transformers faiss-cpu tqdm
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (1.2.7)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (2.2.6)
# Requirement already satisfied: sentence-transformers in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (5.2.0)
# Requirement already satisfied: faiss-cpu in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (1.13.2)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\envs\ai-agent\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
import sys
import pandas as pd

print(sys.version)
print(pd.__version__)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# 2.3.3

# %%
from google_play_scraper import reviews

# %% [markdown]
#  Daily Review Ingestion Agent
#
# Each day's app reviews are ingested as a separate batch,
# simulating real-world daily feedback ingestion.

# %%
from datetime import datetime

# App configuration
APP_ID = "in.swiggy.android"
LANG = "en"
COUNTRY = "in"

# Date configuration
START_DATE = datetime(2024, 6, 1)
TARGET_DATE = datetime(2024, 6, 30)

# Similarity threshold
SIMILARITY_THRESHOLD = 0.85

# %%
test_day = START_DATE
sample_reviews = fetch_daily_reviews(APP_ID, test_day)

print(f"Fetched {len(sample_reviews)} reviews for {test_day.date()}")

if sample_reviews:
    print("\nSample review:")
    print(sample_reviews[0])
else:
    print("No reviews found for this date (this is acceptable).")
# Out:
# Fetched 0 reviews for 2024-06-01
# No reviews found for this date (this is acceptable).

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# %%
# Load a lightweight sentence embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
from datetime import timedelta

def collect_reviews(app_id, start_date, days=7):
    all_reviews = []

    for i in range(days):
        day = start_date + timedelta(days=i)
        daily = fetch_daily_reviews(app_id, day)
        all_reviews.extend(daily)

    return all_reviews

# %%
START_DATE = datetime(2024, 6, 1)
reviews_text = collect_reviews(APP_ID, START_DATE, days=7)

print("Total reviews collected:", len(reviews_text))
# Out:
# Total reviews collected: 0

# %%
if len(reviews_text) == 0:
    reviews_text = [
        "The app is very slow",
        "I love the new update",
        "Too many ads",
        "Great user experience",
        "App crashes frequently"
    ]
    print("Using fallback sample reviews")
# Out:
# Using fallback sample reviews

# %%
embeddings = model.encode(reviews_text, show_progress_bar=True)

print("Embeddings shape:", embeddings.shape)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Embeddings shape: (5, 384)

# %%
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))

print("FAISS index size:", index.ntotal)
# Out:
# FAISS index size: 5

# %%
def search_similar_reviews(query, top_k=5):
    query_embedding = model.encode([query])
    distances, indices = index.search(np.array(query_embedding), top_k)

    results = []
    for idx in indices[0]:
        results.append(reviews_text[idx])

    return results

# %%
query = "app is slow and crashes"
results = search_similar_reviews(query)

print("Query:", query)
print("\nSimilar reviews:")
for r in results:
    print("-", r)
# Out:
# Query: app is slow and crashes
#
# Similar reviews:
# - App crashes frequently
# - The app is very slow
# - Too many ads
# - Great user experience
# - I love the new update

# %%
from collections import Counter

def detect_trends(reviews):
    keywords = ["slow", "crash", "ads", "update", "bug", "great", "love"]
    counter = Counter()

    for r in reviews:
        text = r.lower()
        for k in keywords:
            if k in text:
                counter[k] += 1

    return counter

# %%
trends = detect_trends(reviews_text)

print("Detected review trends:")
for k, v in trends.items():
    print(f"{k}: {v}")
# Out:
# Detected review trends:
# slow: 1
# update: 1
# love: 1
# ads: 1
# great: 1
# crash: 1
